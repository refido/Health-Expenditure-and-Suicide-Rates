# %% [markdown]
# # Kuis
#
# NIM: 2241727028
#
# Nama: Refido Berliano Hartawan
#
# Kelas: TI-4J

# %% [markdown]
# ### Persiapan Data

# %%
# import package
import numpy as np
import pandas as pd

# %%
# baca data
data = pd.read_csv('WHO_MHExp_and_Deaths.csv')
data.head()
# Out:
#   Country_Name  Year  Population  Deaths_All_Types  Deaths_Suicides  \
# 0      Armenia  2006   3219235.0             54404               78
# 1      Armenia  2007   3107395.5             53660                0
# 2      Armenia  2008   3234031.0             54824               63
# 3      Armenia  2009   3066044.0             55120               53
# 4      Armenia  2012   3024127.0             55200               79
#
#    HExp_Pctage_Y  MHExp_Pctage_2011  Dep_Num_2015  Suicide_p100
# 0           5.85               3.38          4.99          5.36
# 1           5.50               3.38          4.99          5.02
# 2           6.64               3.38          4.99          4.23
# 3           8.44               3.38          4.99          4.06
# 4           9.13               3.38          4.99          6.39

# %%
# pemahaman terhadap data
# ukuran data
data.shape

# info data
data.info()

# deskripsi data
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 531 entries, 0 to 530
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country_Name       531 non-null    object
#  1   Year               531 non-null    int64
#  2   Population         531 non-null    float64
#  3   Deaths_All_Types   531 non-null    int64
#  4   Deaths_Suicides    531 non-null    int64
#  5   HExp_Pctage_Y      531 non-null    float64
#  6   MHExp_Pctage_2011  531 non-null    float64
#  7   Dep_Num_2015       531 non-null    float64
#  8   Suicide_p100       531 non-null    float64
# dtypes: float64(5), int64(3), object(1)
# memory usage: 37.5+ KB
#               Year    Population  Deaths_All_Types  Deaths_Suicides  \
# count   531.000000  5.310000e+02      5.310000e+02       531.000000
# mean   2009.694915  2.535148e+07      4.322763e+05       259.659134
# std       5.572266  3.285463e+07      5.856799e+05      1075.051391
# ...

# %% [markdown]
# ### Visualisasi Data

# %%
# import library untuk visualisasi
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# operasi visualisasi
sns.pairplot(data, x_vars=['Year','Suicide_p100','Deaths_Suicides'], 
             y_vars='Population', height=4, aspect=1, kind='scatter')
plt.show()

# %%
sns.heatmap(data.corr(), cmap="YlGnBu", annot = True)
plt.show()

# %% [markdown]
# dari bentuk visualisasi di atas terlihat bahwa Deaths_All_Types memiliki korelasi yang paling kuat terhadap Population

# %% [markdown]
# ### Regresi Linier

# %%
# Buat variabel bebas X dan Y, sebagai contoh ambil dari hasil analisis korelasi dari kegaitan sebelumnya
X = data['Population']
y = data['Deaths_All_Types']

# %%
# Buat pemisahan data uji dan data latih dengan proporsi 7:3
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.7, 
                                                    test_size = 0.3, random_state = 100)

# %%
# hasil training dtaset
X_train
y_train
# Out:
# 450      41176
# 129     109046
# 380     769576
# 239    1199396
# 21      286946
#         ...
# 526     304070
# 53      439076
# 350     306726
# 79      863276
# 520     267220
# Name: Deaths_All_Types, Length: 371, dtype: int64

# %%
# training model
import statsmodels.api as sm

X_train_sm = sm.add_constant(X_train)

# %%
# fitting garis regresi
lr = sm.OLS(y_train, X_train_sm).fit()
lr.params
# Out:
# const        -6494.374407
# Population       0.017079
# dtype: float64

# %%
# analisis statistika dari garis regresi
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:       Deaths_All_Types   R-squared:                       0.923
# Model:                            OLS   Adj. R-squared:                  0.923
# Method:                 Least Squares   F-statistic:                     4421.
# Date:                Wed, 21 Sep 2022   Prob (F-statistic):          1.70e-207
# Time:                        14:34:14   Log-Likelihood:                -4991.2
# No. Observations:                 371   AIC:                             9986.
# Df Residuals:                     369   BIC:                             9994.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -6494.3744   1.12e+04     -0.581      0.561   -2.85e+04    1.55e+04
# ...

# %%
# visualisasi garis regresi
plt.scatter(X_train, y_train)
plt.plot(X_train, 265.2483 + 66.3015*X_train, 'r')
plt.show()

# %% [markdown]
# ### Residual Analysis
# dipakai untuk mengetahui tingkat error dari variabel yang dipengaruhi (y)
#
# Error = Actual y value - y predicted value

# %%
# prediksi y_value dari data x yang telah dilatih
y_train_pred = lr.predict(X_train_sm)

res = (y_train - y_train_pred)

# %%
# cek histogram apakah berdistribusi normal atau tidak
fig = plt.figure()
sns.displot(res, bins = 15)
plt.title('Error Terms', fontsize = 15)
plt.xlabel('y_train - y_train_pred', fontsize = 15)
plt.show()

# %%
plt.scatter(X_train,res)
plt.show()

# %%
# prediksi pada data uji dan evaluasi model
X_test_sm = sm.add_constant(X_test)

# prediksi y value yang berkorelasi dengan X_test_sm
y_test_pred = lr.predict(X_test_sm)

# cetak 5 data terprediksi teratas
y_test_pred.head()
# Out:
# 391    172894.748888
# 474    145937.305701
# 421     54123.259099
# 310    497514.970342
# 302     26420.331822
# dtype: float64

# %%
# hitung nilai r^2
from sklearn.metrics import r2_score

r_squared = r2_score(y_test, y_test_pred)
r_squared
# Out:
# 0.9407414359662741

# %% [markdown]
# perlu diperhatikan bahwa r^2 dari data training adalah 0.940 sedangkan dari data testing adalah 0.923. Hal ini berarti model yang dibentuk cukup stabil (tidak berselisih jauh antara training dengan testing)

# %%
# visualisasi data
plt.scatter(X_test, y_test)
plt.plot(X_test, y_test_pred, 'r')
plt.show()
